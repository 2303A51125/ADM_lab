# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51125/ADM_lab/blob/main/ADM_lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
data = pd.read_csv('/content/podcasts.csv')
data.head()
# Out:
#                        id                                               name  \
# 0  0oonytZGcyIWv9YwCkIEmQ        [MHA Podfic] Sharper Than a Serpent's Tooth
# 1  5AFkDkmHdxzA4hbEamprhX        #Unfollow: Breaking Social Media Addictions
# 2  0glmeSy8kDcr0InwjQuA6N                                  Actively Autistic
# 3  24P0gjO9AG8lG5rFGtyRdZ  ADHD Awareness: Understanding Girls & Women wi...
# 4  4jvSJ5oLlfzqkaHNVaQUxF                                     ADHD Book Club
#
#               publisher                                        description  \
# 0            PurpleStar  This is a My Hero Academia podfic (fanfic audi...
# 1              Unfollow  #Unfollow is a podcast featuring informative t...
# 2     Actively Autistic  The community that was created on Facebook and...
# 3  ADHD Awareness Month  Our podcast features Ellen B. Littman, a clini...
# 4  Distracted Dialogues  ADHD Book Club is a podcast that celebrates re...
#
#    total_episodes  languages media_type  explicit
# ...

# %%
print(data.isnull().sum())
data['total_episodes'].fillna(data['total_episodes'].mean(), inplace=True)
# Replace 'mediam' with 'median' to calculate the median
data['total_episodes'].fillna(data['total_episodes'].median(), inplace=True)
data['total_episodes'].fillna(data['total_episodes'].mode()[0], inplace=True)
print(data.isnull().sum())
# Out:
# id                0
# name              0
# publisher         0
# description       0
# total_episodes    0
# languages         0
# media_type        0
# explicit          0
# dtype: int64
# id                0
# name              0
# publisher         0
# description       0
# total_episodes    0
# languages         0
# media_type        0
# explicit          0
# dtype: int64
# <ipython-input-26-2754bed62c5a>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
# ...

# %%
scaler = MinMaxScaler()
columns_to_normalize = ['total_episodes']
data[columns_to_normalize].head()
# Out:
#    total_episodes
# 0              10
# 1              22
# 2              75
# 3               2
# 4              75

# %%
scaler = StandardScaler()
data[columns_to_normalize] = scaler.fit_transform(data[columns_to_normalize])
data = data.dropna(subset=['total_episodes'])
data[columns_to_normalize].head()
# Out:
#    total_episodes
# 0       -0.514948
# 1       -0.425774
# 2       -0.031920
# 3       -0.574398
# 4       -0.031920
